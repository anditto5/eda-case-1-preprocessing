# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp


# using the Csv file
df = pd.read_csv('C:/Users/gito2/OneDrive/Documents/GitHub/eda-case-1-preprocessing/data/jakarta.csv') 
  
# Checking the first 5 entries of dataset
df.head()

data = df
  
# Finding the missing values
data.isna().any()
  
# Finding if missing values 
data.isnull().any()

data = df
  
# Finding the missing values
data.isna().any()
  
# Finding if missing values 
data.isnull().any()


data.harga.unique()
  
# Here it contains '?', so we Drop it
data = data[data.harga != '?']
  
# checking it again
data.dtypes
# Out:
# created_at      object
# LT             float64
# LB             float64
# KT             float64
# KM             float64
# garasi         float64
# carport        float64
# lokasi          object
# sertifikat      object
# listrik        float64
# hadap           object
# harga          float64
# URL             object
# deskripsi       object
# Unnamed: 14    float64
# Unnamed: 15    float64
# Unnamed: 16    float64
# Unnamed: 17    float64
# Unnamed: 18    float64
# Unnamed: 19    float64
# Unnamed: 20    float64
# Unnamed: 21    float64
# Unnamed: 22    float64
# Unnamed: 23    float64
# Unnamed: 24    float64
# Unnamed: 25    float64
# dtype: object

# %%
# using the Csv file
df = pd.read_csv('C:/Users/gito2/OneDrive/Documents/GitHub/eda-case-1-preprocessing/data/bekasi.csv') 
  
# Checking the first 5 entries of dataset
df.head()

data = df
  
# Finding the missing values
data.isna().any()
  
# Finding if missing values 
data.isnull().any()

data = df
  
# Finding the missing values
data.isna().any()
  
# Finding if missing values 
data.isnull().any()


data.harga.unique()
  
# Here it contains '?', so we Drop it
data = data[data.harga != '?']
  
# checking it again
data.dtypes
# Out:
# created_at      object
# LT             float64
# LB             float64
# KT             float64
# KM             float64
# garasi         float64
# carport        float64
# lokasi          object
# sertifikat      object
# listrik        float64
# hadap           object
# harga          float64
# URL             object
# deskripsi       object
# Unnamed: 14    float64
# Unnamed: 15    float64
# Unnamed: 16    float64
# Unnamed: 17    float64
# Unnamed: 18    float64
# Unnamed: 19    float64
# Unnamed: 20    float64
# Unnamed: 21    float64
# Unnamed: 22    float64
# Unnamed: 23    float64
# Unnamed: 24    float64
# Unnamed: 25    float64
# dtype: object

# %%
# using the Csv file
df = pd.read_csv('C:/Users/gito2/OneDrive/Documents/GitHub/eda-case-1-preprocessing/data/tangerang.csv') 
  
# Checking the first 5 entries of dataset
df.head()

data = df
  
# Finding the missing values
data.isna().any()
  
# Finding if missing values 
data.isnull().any()

data = df
  
# Finding the missing values
data.isna().any()
  
# Finding if missing values 
data.isnull().any()


data.harga.unique()
  
# Here it contains '?', so we Drop it
data = data[data.harga != '?']
  
# checking it again
data.dtypes
# Out:
# created_at      object
# LT             float64
# LB             float64
# KT             float64
# KM             float64
# garasi         float64
# carport        float64
# lokasi          object
# sertifikat      object
# listrik        float64
# hadap           object
# harga          float64
# URL             object
# deskripsi       object
# Unnamed: 14    float64
# Unnamed: 15    float64
# Unnamed: 16    float64
# Unnamed: 17    float64
# Unnamed: 18    float64
# Unnamed: 19    float64
# Unnamed: 20    float64
# Unnamed: 21    float64
# Unnamed: 22    float64
# Unnamed: 23    float64
# Unnamed: 24    float64
# Unnamed: 25    float64
# dtype: object

# %%
# using the Csv file
df = pd.read_csv('C:/Users/gito2/OneDrive/Documents/GitHub/eda-case-1-preprocessing/data/bogor.csv') 
  
# Checking the first 5 entries of dataset
df.head()

data = df
  
# Finding the missing values
data.isna().any()
  
# Finding if missing values 
data.isnull().any()

data = df
  
# Finding the missing values
data.isna().any()
  
# Finding if missing values 
data.isnull().any()


data.harga.unique()
  
# Here it contains '?', so we Drop it
data = data[data.harga != '?']
  
# checking it again
data.dtypes
# Out:
# created_at      object
# LT             float64
# LB             float64
# KT             float64
# KM             float64
# garasi         float64
# carport        float64
# lokasi          object
# sertifikat      object
# listrik        float64
# hadap           object
# harga          float64
# URL             object
# deskripsi       object
# Unnamed: 14    float64
# Unnamed: 15    float64
# Unnamed: 16    float64
# Unnamed: 17    float64
# Unnamed: 18    float64
# Unnamed: 19    float64
# Unnamed: 20    float64
# Unnamed: 21    float64
# Unnamed: 22    float64
# Unnamed: 23    float64
# Unnamed: 24    float64
# Unnamed: 25    float64
# dtype: object
